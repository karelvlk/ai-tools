# %%
import numpy as np

from pca import pca_visualizer
from tsne import tsne_visualizer

# %%
data_dict = {
    'C1': np.random.rand(50, 10),  # 50 samples, 10 features each
    'C2': np.random.rand(50, 10),  # 50 samples, 10 features each
    'C3': np.random.rand(50, 10)   # 50 samples, 10 features each
}

# %%
pca_visualizer(data_dict)

# %%
tsne_visualizer(data_dict)
